# %% [markdown]
# API 4 - Procesamiento de datos
# Oscar Pérez - DNI: 95656916

# %% [markdown]
# 1 -Instalar la librería de python tk y la librería matplotlib.
# Luego dejar una captura de pantalla de las 2 herramientas instaladas.
# (Sugerencia capturar la ventanita de tk, para esto revisar comando tkinter).

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\epere\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib
print("La versión de matplotlib instalada es: ",matplotlib.__version__)
# Out:
# La versión de matplotlib instalada es:  3.10.3

# %%
pip install tk
# Out:
# Collecting tk
#   Downloading tk-0.1.0-py3-none-any.whl.metadata (693 bytes)
# Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: tk
# Successfully installed tk-0.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tkinter
print("La versión de tkinter instalada es: ", tkinter.TkVersion)
# Out:
# La versión de tkinter instalada es:  8.6

# %% [markdown]
# 2 - Ejecutar el siguiente ejercicio y colocar la captura de pantalla de la gráfica
# que generó.

# %%
import matplotlib.pyplot as plt

x = [5, 2, 9, 4, 7]
y = [10, 5, 8, 4, 2]
plt.plot(x, y)
plt.title("Gráfico de API 4")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %% [markdown]
# 3- De una gráfica, generar el ejercicio necesario para obtenerlo, se deja
# ejemplo de cómo sería el código, rellenar lo necesario:

# %%
import matplotlib.pyplot as plt

x = [2,4,5,7,9]
y = [5,4,10,2,8]
plt.bar(x, y)
plt.title("Gráfico de API 4")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %% [markdown]
# 4 - Ejecutar el siguiente ejercicio, compartir una captura de pantalla,
# cambiando el título y modificando cantidades de frutas.

# %%
import matplotlib.pyplot as plt

data = {'manzanas': 20, 'naranjas': 35, 'limones': 15, 'peras': 40}
Nombres= list(data.keys())
Valores= list(data.values())
fig, axs = plt.subplots(1, 3, figsize=(20, 4), sharey=False)
axs[0].bar(Nombres, Valores)
axs[1].scatter(Nombres, Valores)
axs[2].plot(Nombres, Valores)
fig.suptitle('Cantidades y Tipos')
plt.show()
